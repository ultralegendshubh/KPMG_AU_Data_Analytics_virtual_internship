# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from joblib import dump,load 
from sklearn import metrics
import warnings 
import numpy as np

pd.options.display.float_format = '{:.4f}'.format
np.set_printoptions(suppress=True)
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ICICI\\Desktop\\New folder\\Project\\KPMG_AU_Data_Analytics_virtual_internship'

# %%
df_Transactions = pd.read_excel("kpmg_data.xlsx", sheet_name = "Transactions")

# %%
df_Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25        0.0000
# 1               2           3         3120       2017-05-21        1.0000
# 2               3          37          402       2017-10-16        0.0000
# 3               4          88         3135       2017-08-31        0.0000
# 4               5          78          787       2017-10-01        1.0000
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
df_CustomerDemographic = pd.read_excel("kpmg_data.xlsx", sheet_name= "CustomerDemographic")

# %%
df_CustomerDemographic.head(5)
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
df_CustomerAddress = pd.read_excel("kpmg_data.xlsx", sheet_name = "CustomerAddress")

# %%
df_CustomerAddress.head(5)
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
df_Transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
#Missing Values
df_Transactions.isna().mean()*100
# Out:
# transaction_id            0.0000
# product_id                0.0000
# customer_id               0.0000
# transaction_date          0.0000
# online_order              1.8000
# order_status              0.0000
# brand                     0.9850
# product_line              0.9850
# product_class             0.9850
# product_size              0.9850
# list_price                0.0000
# standard_cost             0.9850
# product_first_sold_date   0.9850
# dtype: float64

# %%
#Missing values is less than 2% of all records so we can drop them

df_Transactions.dropna(inplace=True)

# %%
df_Transactions.shape
# Out:
# (19445, 13)

# %%
df_Transactions.isna().mean()*100
# Out:
# transaction_id            0.0000
# product_id                0.0000
# customer_id               0.0000
# transaction_date          0.0000
# online_order              0.0000
# order_status              0.0000
# brand                     0.0000
# product_line              0.0000
# product_class             0.0000
# product_size              0.0000
# list_price                0.0000
# standard_cost             0.0000
# product_first_sold_date   0.0000
# dtype: float64

# %%
df_Transactions["order_status"].value_counts()
# Out:
# Approved     19273
# Cancelled      172
# Name: order_status, dtype: int64

# %%
df_Transactions["brand"].value_counts()
# Out:
# Solex             4169
# WeareA2B          3245
# Giant Bicycles    3244
# OHM Cycles        2993
# Trek Bicycles     2931
# Norco Bicycles    2863
# Name: brand, dtype: int64

# %%
df_Transactions["product_line"].value_counts()
# Out:
# Standard    13920
# Road         3894
# Touring      1213
# Mountain      418
# Name: product_line, dtype: int64

# %%
df_CustomerDemographic.isna().mean()*100
# Out:
# customer_id                            0.0000
# first_name                             0.0000
# last_name                              3.1250
# gender                                 0.0000
# past_3_years_bike_related_purchases    0.0000
# DOB                                    2.1750
# job_title                             12.6500
# job_industry_category                 16.4000
# wealth_segment                         0.0000
# deceased_indicator                     0.0000
# default                                7.5500
# owns_car                               0.0000
# tenure                                 2.1750
# dtype: float64

# %%
df_CustomerDemographic["job_title"].value_counts()
# Out:
# Business Systems Development Analyst    45
# Tax Accountant                          44
# Social Worker                           44
# Internal Auditor                        42
# Recruiting Manager                      41
#                                         ..
# Database Administrator I                 4
# Health Coach I                           3
# Health Coach III                         3
# Research Assistant III                   3
# Developer I                              1
# Name: job_title, Length: 195, dtype: int64

# %%
df_CustomerDemographic["job_industry_category"].value_counts()
# Out:
# Manufacturing         799
# Financial Services    774
# Health                602
# Retail                358
# Property              267
# IT                    223
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: job_industry_category, dtype: int64

# %%
df_CustomerDemographic.drop(['default'], axis=1)
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley  Unknow
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 1954-01-20      Recruiting Manager
# ...

# %%
df_CustomerDemographic['job_title'].fillna('Not Available', inplace=True)

# %%
df_CustomerDemographic['job_industry_category'].fillna('Not Available', inplace=True)

# %%
df_CustomerDemographic.drop(['default'], axis=1, inplace=True )

# %%
df_CustomerDemographic['tenure'] = df_CustomerDemographic['tenure'].fillna(df_CustomerDemographic['tenure'].mode()[0])

# %%
df_CustomerDemographic['DOB'] = df_CustomerDemographic['DOB'].fillna(df_CustomerDemographic['DOB'].mode()[0])

# %%
df_CustomerDemographic.isna().mean()*100
# Out:
# customer_id                           0.0000
# first_name                            0.0000
# last_name                             3.1250
# gender                                0.0000
# past_3_years_bike_related_purchases   0.0000
# DOB                                   0.0000
# job_title                             0.0000
# job_industry_category                 0.0000
# wealth_segment                        0.0000
# deceased_indicator                    0.0000
# owns_car                              0.0000
# tenure                                0.0000
# dtype: float64

# %%
df_CustomerDemographic["full_name"] = df_CustomerDemographic['first_name'].astype(str) +" "+ df_CustomerDemographic["last_name"]

# %%
df_CustomerDemographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley  Unknow
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 1954-01-20      Recruiting Manager
# ...

# %%
df_CustomerDemographic.drop(['full_name'], axis=1)
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley  Unknow
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 1954-01-20      Recruiting Manager
# ...

# %%
df_CustomerDemographic.isna().mean()*100
# Out:
# customer_id                           0.0000
# first_name                            0.0000
# last_name                             3.1250
# gender                                0.0000
# past_3_years_bike_related_purchases   0.0000
# DOB                                   0.0000
# job_title                             0.0000
# job_industry_category                 0.0000
# wealth_segment                        0.0000
# deceased_indicator                    0.0000
# owns_car                              0.0000
# tenure                                0.0000
# full_name                             3.1250
# dtype: float64

# %%
# determining the name of the file
file_name = 'CustomerDemographic.xlsx'
  
# saving the excel
df_CustomerDemographic.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# determining the name of the file
file_name2 = 'Transactions.xlsx'
  
# saving the excel
df_Transactions.to_excel(file_name2)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
df_NewCustomerList = pd.read_excel("kpmg_data.xlsx", sheet_name = "NewCustomerList")

# %%
df_NewCustomerList
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
df_NewCustomerList.describe()
# Out:
#        past_3_years_bike_related_purchases    tenure  postcode  \
# count                            1000.0000 1000.0000 1000.0000
# mean                               49.8360   11.3880 3019.2270
# std                                27.7967    5.0371  848.8958
# min                                 0.0000    0.0000 2000.0000
# 25%                                26.7500    7.0000 2209.0000
# 50%                                51.0000   11.0000 2800.0000
# 75%                                72.0000   15.0000 3845.5000
# max                                99.0000   22.0000 4879.0000
#
#        property_valuation  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# count           1000.0000    1000.0000    1000.0000    1000.0000    1000.0000
# mean               7.3970       0.7463       0.8375       0.9413       0.8702
# std                2.7588       0.2055       0.2475       0.2954       0.2854
# min                1.0000       0.4000       0.4000       0.4100       0.3485
# ...

# %%
df_NewCustomerList.isna().mean()*100
# Out:
# first_name                             0.0000
# last_name                              2.9000
# gender                                 0.0000
# past_3_years_bike_related_purchases    0.0000
# DOB                                    1.7000
# job_title                             10.6000
# job_industry_category                 16.5000
# wealth_segment                         0.0000
# deceased_indicator                     0.0000
# owns_car                               0.0000
# tenure                                 0.0000
# address                                0.0000
# postcode                               0.0000
# state                                  0.0000
# country                                0.0000
# property_valuation                     0.0000
# Unnamed: 16                            0.0000
# Unnamed: 17                            0.0000
# Unnamed: 18                            0.0000
# Unnamed: 19                            0.0000
# ...

# %%
df_NewCustomerList["job_title"].value_counts()
# Out:
# Associate Professor         15
# Environmental Tech          14
# Software Consultant         14
# Chief Design Engineer       13
# Assistant Manager           12
#                             ..
# Accountant II                1
# Programmer IV                1
# Administrative Officer       1
# Accounting Assistant III     1
# Web Developer I              1
# Name: job_title, Length: 184, dtype: int64

# %%
df_NewCustomerList["job_industry_category"].value_counts()
# Out:
# Financial Services    203
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: job_industry_category, dtype: int64

# %%
df_NewCustomerList['job_title'].fillna('Not Available', inplace=True)

# %%
df_NewCustomerList['job_industry_category'].fillna('Not Available', inplace=True)

# %%
df_NewCustomerList.isna().mean()*100
# Out:
# first_name                            0.0000
# last_name                             2.9000
# gender                                0.0000
# past_3_years_bike_related_purchases   0.0000
# DOB                                   1.7000
# job_title                             0.0000
# job_industry_category                 0.0000
# wealth_segment                        0.0000
# deceased_indicator                    0.0000
# owns_car                              0.0000
# tenure                                0.0000
# address                               0.0000
# postcode                              0.0000
# state                                 0.0000
# country                               0.0000
# property_valuation                    0.0000
# Unnamed: 16                           0.0000
# Unnamed: 17                           0.0000
# Unnamed: 18                           0.0000
# Unnamed: 19                           0.0000
# Unnamed: 20                           0.0000
# ...

# %%
# determining the name of the file
file_name3 = 'NewCustomerList.xlsx'
  
# saving the excel
df_NewCustomerList.to_excel(file_name3)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %% [markdown]
# # Data Modeling is Completed
